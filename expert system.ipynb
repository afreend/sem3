# %%
import time
print("\t\twelcome to automobile AI expert system\t\t")
print("\n\nAI : do you have any problem with your vehicle ? (yes or no)\n")
choice1 =input("you:")

if choice1 == "yes":
    print("\nenter the type of your issue listen down below\n1. starting trouble\n2. wobble while driving\n3.I didn't have issue\n")
    choice2 =input("\nenter here (number only):")
          
    if choice2 > "3" or choice2 <"1":
        print("\nAI : please enter valid key..")
          
    elif choice2 =="3":
        print("\nAI : then , why are you enter yes in the first question...you fool")
          
    elif choice2 =="2":
        print("\nAI :ok let me think...!\n")
        for i in range(1,20):
            time.sleep(0.08)
            print(".",flush=True,end="")
        print("\nAI : when do you feel the woubbling\n1. while deive on the highway at terrible speed\n2.while drive normal road\n")
                
        choice3 =input("YOU :")
                
        if choice3 == "1":
            print("\nAI : please wait still...\nAI : I wanna call police...\nAI : just kidding...go slow my friend")
                      
        elif choice3 == "2":
            print("\nAI : check you tire  air pressure then check inform me kindely")
            print("nAI : still you feel wobble?(yes or no)\n")
            choice4 =input("you :")
                      
            if choice4 == "no":
                print("\nAI : i'm glad to helped you....\nthank you...!\call me again")
                      
                      
            elif choice4 =="yes":
                print("\nAI : i think,you have to make a phone call to your service center....\n thank you")
            else:
                print("\nAI : will ypu please enter the correct answer...\ngo on run again")
        else:
            print("\nAI : please enter valid key...")
                    
    else:
        print("\nAI : let us remember that you have to check that the key is inserted?\nAI : is it inserted?(yes or no)")
        choice5 = input("YOU : ")
        
        if choice5 == 'no':
            print("\nAI : i think you have to study hard...better than ride a bike ..\nAI : thank you..!")
                      
        elif choice5 == 'yes':
            print("\nAI : oh i see..let me think what to do wait a")
                       
            for i in range(1,30):
                time.sleep(0.08)
                print(".",flush=True,end="")
                           
            print("\nAI : sorry buddy i did't get anything in my mind,i think you to reach service center.")
        else:
            print("\ni'm geting bore when you enetr wrong answer, ' {} ' it does't make any scene".format(choice5))                      
                      
elif choice1=='no':
    print("\nAI : why are you write my time...")
else:
    print("AI : enetr valid key")
# Out:
# 		welcome to automobile AI expert system
#
#
# AI : do you have any problem with your vehicle ? (yes or no)
#
# you:yes
#
# enter the type of your issue listen down below
# 1. starting trouble
# 2. wobble while driving
# 3.I didn't have issue
#
#
# enter here (number only):2
#
# AI :ok let me think...!
#
# ...................
# AI : when do you feel the woubbling
# 1. while deive on the highway at terrible speed
# 2.while drive normal road
#
# YOU :2
#
# AI : check you tire  air pressure then check inform me kindely
# nAI : still you feel wobble?(yes or no)
#
# you :yes
#
# AI : i think,you have to make a phone call to your service center....
#  thank you
